# %% [markdown]
# <a href="https://colab.research.google.com/github/MadihaObaid/final_exam/blob/main/Question1_DP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install mlxtend
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.9/dist-packages (0.21.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from mlxtend) (57.4.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.9/dist-packages (from mlxtend) (1.2.1)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.9/dist-packages (from mlxtend) (1.10.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.9/dist-packages (from mlxtend) (1.22.4)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from mlxtend) (3.5.3)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.9/dist-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.9/dist-packages (from mlxtend) (1.3.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.39.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->mlxtend) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->mlxtend) (8.4.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.2->mlxtend) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.15.0)

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python2.7 1

# %%
# !python3 --version
# Out:
# Python 3.9.16

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from prettytable import PrettyTable
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns  import apriory
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-bd4bf60ab471> in <module>
#       5 from prettytable import PrettyTable
#       6 from mlxtend.preprocessing import TransactionEncoder
# ----> 7 from mlxtend.frequent_patterns  import apriory
#
# ImportError: cannot import name 'apriory' from 'mlxtend.frequent_patterns' (/usr/local/lib/python3.9/dist-packages/mlxtend/frequent_patterns/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5973 sha256=cab9f56356de20dbd11eafbceb4dc57dff8763013fcf5ebf22d4cee5c54b9110
#   Stored in directory: /root/.cache/pip/wheels/32/2a/54/10c595515f385f3726642b10c60bf788029e8f3a1323e3913a
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
from apyori import apriori

# %%
data = [['bread'],
 ['scandinavian'],
 ['cookies', 'hot chocolate', 'jam'],
 ['muffin'],
 ['bread', 'coffee', 'pastry'],
 ['medialuna', 'muffin', 'pastry'],
 ['coffee', 'medialuna', 'pastry', 'tea'],
 ['bread', 'pastry'],
 ['bread', 'muffin'],
 ['medialuna', 'scandinavian'],
 ['bread', 'medialuna'],
 ['coffee', 'jam', 'pastry', 'tartine', 'tea'],
 ['basket', 'bread', 'coffee'],
 ['bread', 'medialuna', 'pastry'],
 ['mineral water', 'scandinavian'],
 ['bread', 'coffee', 'medialuna'],
 ['hot chocolate'],
 ['farm house'],
 ['bread', 'farm house'],
 ['jam'],
 ['muffin', 'scandinavian'],
 ['fudge'],
 ['bread', 'coffee'],
 ['bread', 'jam'],
 ['basket'],
 ['coffee'],
 ['coffee', 'muffin'],
 ['bread', 'tea'],
 ['coffee', 'juice', 'muffin', 'tartine'],
 ['fudge', 'scandinavian'],
 ['coffee', 'medialuna'],
 ['coffee', 'hot chocolate', 'medialuna'],
 ['bread', "ella's kitchen pouches", 'jam', 'juice', 'muffin'],
 ['bread', 'victorian sponge'],
 ['coffee', 'frittata', 'hearty & seasonal', 'tea'],
 ['coffee', 'frittata'],
 ['hot chocolate', 'soup', 'tea', 'victorian sponge'],
 ['tea'],
 ['coffee', 'cookies', 'juice'],
 ['coffee', 'hearty & seasonal', 'pick and mix bowls', 'smoothies'],
 ['cake'],
 ['coffee', 'mighty protein', 'tartine', 'tea'],
 ['frittata', 'hearty & seasonal', 'mineral water'],
 ['hearty & seasonal', 'mineral water', 'muffin'],
 ['chicken sand', 'coffee', 'frittata', 'scandinavian', 'tea'],
 ['bread', 'tea', 'victorian sponge'],
 ['frittata', 'jam'],
 ['coffee', 'fudge', 'muffin', 'tea'],
 ['bread', 'coffee', 'frittata'],
 ['cake', 'coffee'],
 ['bread', 'tartine'],
 ['coffee', 'medialuna', 'pastry'],
 ['juice'],
 ['coffee', 'jam'],
 ['bread', 'coke'],
 ['farm house', 'pastry', 'tea'],
 ['coffee', 'juice', 'pastry'],
 ['coffee', 'pastry'],
 ['coffee', 'medialuna', 'muffin'],
 ['cake', 'coffee', 'tea'],
 ['coffee', 'tea'],
 ['farm house', 'muffin'],
 ['bread', 'muffin', 'pastry'],
 ['pastry'],
 ['cake', 'coffee', 'cookies', 'my-5 fruit shoot'],
 ['cookies', 'pastry', 'tea'],
 ['cookies'],
 ['coffee', 'jam', 'juice'],
 ['coffee', 'soup'],
 ['coffee', 'tartine', 'tea'],
 ['cookies', 'juice', 'pick and mix bowls', 'tea'],
 ['hearty & seasonal', 'soup'],
 ['farm house', 'hearty & seasonal', 'tea'],
 ['soup', 'tea'],
 ['coffee', 'hearty & seasonal', 'soup'],
 ['bread', 'hearty & seasonal', 'muffin'],
 ['coffee', 'cookies'],
 ['muffin', 'tea'],
 ['coffee', 'focaccia', 'tea'],
 ['sandwich'],
 ['coffee', 'tartine'],
 ['coffee', 'fudge'],
 ['coke', 'soup'],
 ['coffee', 'cookies', 'muffin', 'tea'],
 ['coffee', 'coke', 'hearty & seasonal', 'mighty protein'],
 ['muffin', 'sandwich', 'tea'],
 ['bread', 'cookies', 'hot chocolate'],
 ['mineral water', 'muffin'],
 ['coffee', 'juice'],
 ['bread', 'hearty & seasonal', 'mineral water', 'sandwich'],
 ['mineral water'],
 ['jam', 'tea'],
 ["ella's kitchen pouches", 'pastry'],
 ['farm house', 'tea'],
 ['tea', 'victorian sponge'],
 ['pastry', 'tea'],
 ['bread', 'scandinavian'],
 ['bread', 'cake', 'cookies'],
 ['coffee', 'pastry', 'scandinavian'],
 ['coffee', 'hearty & seasonal', 'muffin'],
 ['coffee', 'cookies', 'tartine'],
 ['bread', 'cookies'],
 ['tartine'],
 ['alfajores', 'coffee'],
 ['coffee', 'coke', 'soup'],
 ['sandwich', 'soup', 'tea'],
 ['bread', 'hearty & seasonal'],
 ['alfajores'],
 ['bread', 'coffee', 'soup', 'tea'],
 ['coffee', 'sandwich'],
 ['bread', 'cookies', 'pastry', 'tea'],
 ['alfajores', 'juice', 'tea'],
 ['cake', 'coffee', 'muffin', 'soup'],
 ['cake', 'coffee', 'hot chocolate'],
 ['cake', 'cookies'],
 ['alfajores', 'coffee', 'juice'],
 ['coffee', 'soup', 'tea'],
 ['bread', 'eggs'],
 ['medialuna'],
 ['coffee', 'hot chocolate', 'pastry'],
 ['coke'],
 ['alfajores', 'coffee', 'farm house'],
 ['coffee', 'pastry', 'tea'],
 ['coffee', 'farm house'],
 ['farm house', 'pastry'],
 ['alfajores', 'bread', 'juice'],
 ['alfajores', 'bread'],
 ['hearty & seasonal'],
 ['bread', 'jam', 'tartine'],
 ['farm house', 'scandinavian'],
 ['coffee', 'hearty & seasonal', 'muffin', 'scandinavian'],
 ['coffee', 'coke', 'pick and mix bowls', 'tartine'],
 ['alfajores', 'coffee', 'farm house', 'scandinavian'],
 ['juice', 'mineral water', 'soup'],
 ['cookies', 'juice', 'soup', 'tea'],
 ['hearty & seasonal', 'tea'],
 ['coffee', 'juice', 'mineral water', 'soup'],
 ['hearty & seasonal', 'smoothies'],
 ['cookies', 'farm house'],
 ['juice', 'soup', 'tea'],
 ['soup'],
 ['cookies', 'tea'],
 ['bread', 'hearty & seasonal', 'soup'],
 ['alfajores', 'cookies', 'juice', 'mineral water', 'pick and mix bowls'],
 ['juice', 'mighty protein'],
 ['alfajores', 'coffee', 'mineral water'],
 ['coffee', 'mighty protein'],
 ['bread', 'sandwich', 'tea'],
 ['coffee', 'farm house', 'jam'],
 ['focaccia'],
 ['bread', 'my-5 fruit shoot', 'pastry', 'tartine'],
 ['bread', 'coffee', 'tea'],
 ['medialuna', 'pastry'],
 ['alfajores', 'brownie', 'coffee', 'fudge'],
 ['bread', 'cookies', 'fudge'],
 ['coffee', 'jam', 'pastry'],
 ['hearty & seasonal', 'pastry', 'smoothies', 'soup'],
 ['bread',
  'coffee',
  'focaccia',
  'hearty & seasonal',
  'pick and mix bowls',
  'sandwich'],
 ['brownie', 'coffee', 'sandwich'],
 ['brownie', 'cookies'],
 ['bread', 'coffee', 'sandwich'],
 ['coffee', 'hot chocolate'],
 ['brownie', 'farm house', 'focaccia', 'pastry'],
 ['cake', 'focaccia'],
 ['hearty & seasonal', 'mineral water', 'soup'],
 ['cake', 'tea'],
 ['bread', 'focaccia', 'fudge'],
 ['alfajores', 'coffee', 'hot chocolate'],
 ['brownie', 'cake', 'pastry'],
 ['alfajores', 'dulce de leche', 'medialuna'],
 ['alfajores', 'dulce de leche'],
 ['bread', 'cake'],
 ['alfajores', 'bread', 'coffee', 'medialuna'],
 ['dulce de leche'],
 ['alfajores', 'brownie', 'coffee', "ella's kitchen pouches", 'juice'],
 ['alfajores', 'bread', 'brownie', 'cookies', 'juice'],
 ['pick and mix bowls'],
 ['farm house', 'focaccia'],
 ['cookies', "ella's kitchen pouches", 'juice', 'my-5 fruit shoot'],
 ['bread', 'jam', 'tea'],
 ['brownie', 'pastry'],
 ['coffee', 'cookies', 'honey', 'tea'],
 ['brownie'],
 ['bread', 'the bart'],
 ['brownie', 'coffee'],
 ['coffee', 'mineral water', 'tartine'],
 ['brownie', 'juice'],
 ['alfajores', 'bread', 'coffee', 'jam', 'medialuna', 'pastry', 'tea'],
 ['coffee', 'pick and mix bowls'],
 ['coffee', 'mineral water', 'scandinavian', 'soup'],
 ['juice', 'mineral water', 'pick and mix bowls', 'sandwich'],
 ['coffee', 'hearty & seasonal'],
 ['bread', 'coffee', 'hearty & seasonal', 'mineral water'],
 ['brownie', 'coffee', 'sandwich', 'tartine'],
 ['alfajores', 'coffee', 'tartine'],
 ['coffee', 'jam', 'soup'],
 ['brownie', 'mineral water'],
 ['coffee', 'scandinavian'],
 ['brownie', 'coffee', 'hearty & seasonal', 'hot chocolate'],
 ['alfajores', 'coffee', 'tea']]

# %%
data
# Out:
# [['bread'],
#  ['scandinavian'],
#  ['cookies', 'hot chocolate', 'jam'],
#  ['muffin'],
#  ['bread', 'coffee', 'pastry'],
#  ['medialuna', 'muffin', 'pastry'],
#  ['coffee', 'medialuna', 'pastry', 'tea'],
#  ['bread', 'pastry'],
#  ['bread', 'muffin'],
#  ['medialuna', 'scandinavian'],
#  ['bread', 'medialuna'],
#  ['coffee', 'jam', 'pastry', 'tartine', 'tea'],
#  ['basket', 'bread', 'coffee'],
#  ['bread', 'medialuna', 'pastry'],
#  ['mineral water', 'scandinavian'],
#  ['bread', 'coffee', 'medialuna'],
#  ['hot chocolate'],
#  ['farm house'],
#  ['bread', 'farm house'],
#  ['jam'],
#  ['muffin', 'scandinavian'],
#  ['fudge'],
#  ['bread', 'coffee'],
#  ['bread', 'jam'],
#  ['basket'],
#  ['coffee'],
#  ['coffee', 'muffin'],
#  ['bread', 'tea'],
#  ['coffee', 'juice', 'muffin', 'tartine'],
#  ['fudge', 'scandinavian'],
#  ['coffee', 'medialuna'],
#  ['coffee', 'hot chocolate', 'medialuna'],
#  ['bread', "ella's kitchen pouches", 'jam', 'juice', 'muffin'],
#  ['bread', 'victorian sponge'],
#  ['coffee', 'frittata', 'hearty & seasonal', 'tea'],
#  ['coffee', 'frittata'],
#  ['hot chocolate', 'soup', 'tea', 'victorian sponge'],
#  ['tea'],
#  ['coffee', 'cookies', 'juice'],
#  ['coffee', 'hearty & seasonal', 'pick and mix bowls', 'smoothies'],
#  ['cake'],
#  ['coffee', 'mighty protein', 'tartine', 'tea'],
#  ['frittata', 'hearty & seasonal', 'mineral water'],
#  ['hearty & seasonal', 'mineral water', 'muffin'],
#  ['chicken sand', 'coffee', 'frittata', 'scandinavian', 'tea'],
#  ['bread', 'tea', 'victorian sponge'],
#  ['frittata', 'jam'],
#  ['coffee', 'fudge', 'muffin', 'tea'],
#  ['bread', 'coffee', 'frittata'],
#  ['cake', 'coffee'],
#  ['bread', 'tartine'],
#  ['coffee', 'medialuna', 'pastry'],
#  ['juice'],
#  ['coffee', 'jam'],
#  ['bread', 'coke'],
#  ['farm house', 'pastry', 'tea'],
#  ['coffee', 'juice', 'pastry'],
#  ['coffee', 'pastry'],
#  ['coffee', 'medialuna', 'muffin'],
#  ['cake', 'coffee', 'tea'],
#  ['coffee', 'tea'],
#  ['farm house', 'muffin'],
#  ['bread', 'muffin', 'pastry'],
#  ['pastry'],
#  ['cake', 'coffee', 'cookies', 'my-5 fruit shoot'],
#  ['cookies', 'pastry', 'tea'],
#  ['cookies'],
#  ['coffee', 'jam', 'juice'],
#  ['coffee', 'soup'],
#  ['coffee', 'tartine', 'tea'],
#  ['cookies', 'juice', 'pick and mix bowls', 'tea'],
#  ['hearty & seasonal', 'soup'],
#  ['farm house', 'hearty & seasonal', 'tea'],
#  ['soup', 'tea'],
#  ['coffee', 'hearty & seasonal', 'soup'],
#  ['bread', 'hearty & seasonal', 'muffin'],
#  ['coffee', 'cookies'],
#  ['muffin', 'tea'],
#  ['coffee', 'focaccia', 'tea'],
#  ['sandwich'],
#  ['coffee', 'tartine'],
#  ['coffee', 'fudge'],
#  ['coke', 'soup'],
#  ['coffee', 'cookies', 'muffin', 'tea'],
#  ['coffee', 'coke', 'hearty & seasonal', 'mighty protein'],
#  ['muffin', 'sandwich', 'tea'],
#  ['bread', 'cookies', 'hot chocolate'],
#  ['mineral water', 'muffin'],
#  ['coffee', 'juice'],
#  ['bread', 'hearty & seasonal', 'mineral water', 'sandwich'],
#  ['mineral water'],
#  ['jam', 'tea'],
#  ["ella's kitchen pouches", 'pastry'],
#  ['farm house', 'tea'],
#  ['tea', 'victorian sponge'],
#  ['pastry', 'tea'],
#  ['bread', 'scandinavian'],
#  ['bread', 'cake', 'cookies'],
#  ['coffee', 'pastry', 'scandinavian'],
#  ['coffee', 'hearty & seasonal', 'muffin'],
#  ['coffee', 'cookies', 'tartine'],
#  ['bread', 'cookies'],
#  ['tartine'],
#  ['alfajores', 'coffee'],
#  ['coffee', 'coke', 'soup'],
#  ['sandwich', 'soup', 'tea'],
#  ['bread', 'hearty & seasonal'],
#  ['alfajores'],
#  ['bread', 'coffee', 'soup', 'tea'],
#  ['coffee', 'sandwich'],
#  ['bread', 'cookies', 'pastry', 'tea'],
#  ['alfajores', 'juice', 'tea'],
#  ['cake', 'coffee', 'muffin', 'soup'],
#  ['cake', 'coffee', 'hot chocolate'],
#  ['cake', 'cookies'],
#  ['alfajores', 'coffee', 'juice'],
#  ['coffee', 'soup', 'tea'],
#  ['bread', 'eggs'],
#  ['medialuna'],
#  ['coffee', 'hot chocolate', 'pastry'],
#  ['coke'],
#  ['alfajores', 'coffee', 'farm house'],
#  ['coffee', 'pastry', 'tea'],
#  ['coffee', 'farm house'],
#  ['farm house', 'pastry'],
#  ['alfajores', 'bread', 'juice'],
#  ['alfajores', 'bread'],
#  ['hearty & seasonal'],
#  ['bread', 'jam', 'tartine'],
#  ['farm house', 'scandinavian'],
#  ['coffee', 'hearty & seasonal', 'muffin', 'scandinavian'],
#  ['coffee', 'coke', 'pick and mix bowls', 'tartine'],
#  ['alfajores', 'coffee', 'farm house', 'scandinavian'],
#  ['juice', 'mineral water', 'soup'],
#  ['cookies', 'juice', 'soup', 'tea'],
#  ['hearty & seasonal', 'tea'],
#  ['coffee', 'juice', 'mineral water', 'soup'],
#  ['hearty & seasonal', 'smoothies'],
#  ['cookies', 'farm house'],
#  ['juice', 'soup', 'tea'],
#  ['soup'],
#  ['cookies', 'tea'],
#  ['bread', 'hearty & seasonal', 'soup'],
#  ['alfajores', 'cookies', 'juice', 'mineral water', 'pick and mix bowls'],
#  ['juice', 'mighty protein'],
#  ['alfajores', 'coffee', 'mineral water'],
#  ['coffee', 'mighty protein'],
#  ['bread', 'sandwich', 'tea'],
#  ['coffee', 'farm house', 'jam'],
#  ['focaccia'],
#  ['bread', 'my-5 fruit shoot', 'pastry', 'tartine'],
#  ['bread', 'coffee', 'tea'],
#  ['medialuna', 'pastry'],
#  ['alfajores', 'brownie', 'coffee', 'fudge'],
#  ['bread', 'cookies', 'fudge'],
#  ['coffee', 'jam', 'pastry'],
#  ['hearty & seasonal', 'pastry', 'smoothies', 'soup'],
#  ['bread',
#   'coffee',
#   'focaccia',
#   'hearty & seasonal',
#   'pick and mix bowls',
#   'sandwich'],
#  ['brownie', 'coffee', 'sandwich'],
#  ['brownie', 'cookies'],
#  ['bread', 'coffee', 'sandwich'],
#  ['coffee', 'hot chocolate'],
#  ['brownie', 'farm house', 'focaccia', 'pastry'],
#  ['cake', 'focaccia'],
#  ['hearty & seasonal', 'mineral water', 'soup'],
#  ['cake', 'tea'],
#  ['bread', 'focaccia', 'fudge'],
#  ['alfajores', 'coffee', 'hot chocolate'],
#  ['brownie', 'cake', 'pastry'],
#  ['alfajores', 'dulce de leche', 'medialuna'],
#  ['alfajores', 'dulce de leche'],
#  ['bread', 'cake'],
#  ['alfajores', 'bread', 'coffee', 'medialuna'],
#  ['dulce de leche'],
#  ['alfajores', 'brownie', 'coffee', "ella's kitchen pouches", 'juice'],
#  ['alfajores', 'bread', 'brownie', 'cookies', 'juice'],
#  ['pick and mix bowls'],
#  ['farm house', 'focaccia'],
#  ['cookies', "ella's kitchen pouches", 'juice', 'my-5 fruit shoot'],
#  ['bread', 'jam', 'tea'],
#  ['brownie', 'pastry'],
#  ['coffee', 'cookies', 'honey', 'tea'],
#  ['brownie'],
#  ['bread', 'the bart'],
#  ['brownie', 'coffee'],
#  ['coffee', 'mineral water', 'tartine'],
#  ['brownie', 'juice'],
#  ['alfajores', 'bread', 'coffee', 'jam', 'medialuna', 'pastry', 'tea'],
#  ['coffee', 'pick and mix bowls'],
#  ['coffee', 'mineral water', 'scandinavian', 'soup'],
#  ['juice', 'mineral water', 'pick and mix bowls', 'sandwich'],
#  ['coffee', 'hearty & seasonal'],
#  ['bread', 'coffee', 'hearty & seasonal', 'mineral water'],
#  ['brownie', 'coffee', 'sandwich', 'tartine'],
#  ['alfajores', 'coffee', 'tartine'],
#  ['coffee', 'jam', 'soup'],
#  ['brownie', 'mineral water'],
#  ['coffee', 'scandinavian'],
#  ['brownie', 'coffee', 'hearty & seasonal', 'hot chocolate'],
#  ['alfajores', 'coffee', 'tea']]

# %%
te = TransactionEncoder()
te_arry = te.fit(data).transform(data)

# %%
display(te.columns_)
# Out:
# ['alfajores',
#  'basket',
#  'bread',
#  'brownie',
#  'cake',
#  'chicken sand',
#  'coffee',
#  'coke',
#  'cookies',
#  'dulce de leche',
#  'eggs',
#  "ella's kitchen pouches",
#  'farm house',
#  'focaccia',
#  'frittata',
#  'fudge',
#  'hearty & seasonal',
#  'honey',
#  'hot chocolate',
#  'jam',
#  'juice',
#  'medialuna',
#  'mighty protein',
#  'mineral water',
#  'muffin',
#  'my-5 fruit shoot',
#  'pastry',
#  'pick and mix bowls',
#  'sandwich',
#  'scandinavian',
#  'smoothies',
#  'soup',
#  'tartine',
#  'tea',
#  'the bart',
#  'victorian sponge']

# %%
display(te_arry)
# Out:
# array([[False, False,  True, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [ True, False, False, ...,  True, False, False]])

# %%
df = pd.DataFrame(te_arry, columns = te.columns_)

# %%
df
# Out:
#      alfajores  basket  bread  brownie   cake  chicken sand  coffee   coke  \
# 0        False   False   True    False  False         False   False  False
# 1        False   False  False    False  False         False   False  False
# 2        False   False  False    False  False         False   False  False
# 3        False   False  False    False  False         False   False  False
# 4        False   False   True    False  False         False    True  False
# ..         ...     ...    ...      ...    ...           ...     ...    ...
# 195      False   False  False    False  False         False    True  False
# 196      False   False  False     True  False         False   False  False
# 197      False   False  False    False  False         False    True  False
# 198      False   False  False     True  False         False    True  False
# 199       True   False  False    False  False         False    True  False
#
#      cookies  dulce de leche  ...  pastry  pick and mix bowls  sandwich  \
# 0      False           False  ...   False               False     False
# 1      False           False  ...   False               False     False
# 2       True           False  ...   False               False     False
# 3      False           False  ...   False               False     False
# 4      False           False  ...    True               False     False
# ..       ...             ...  ...     ...                 ...       ...
# 195    False           False  ...   False               False     False
# 196    False           False  ...   False               False     False
# 197    False           False  ...   False               False     False
# 198    False           False  ...   False               False     False
# 199    False           False  ...   False               False     False
#
#      scandinavian  smoothies   soup  tartine    tea  the bart  \
# 0           False      False  False    False  False     False
# 1            True      False  False    False  False     False
# 2           False      False  False    False  False     False
# 3           False      False  False    False  False     False
# 4           False      False  False    False  False     False
# ..            ...        ...    ...      ...    ...       ...
# 195         False      False   True    False  False     False
# 196         False      False  False    False  False     False
# 197          True      False  False    False  False     False
# 198         False      False  False    False  False     False
# 199         False      False  False    False   True     False
#
#      victorian sponge
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ..                ...
# 195             False
# 196             False
# 197             False
# 198             False
# 199             False
#
# [200 rows x 36 columns]

# %%
from mlxtend.frequent_patterns import apriori
ratio = 0.1
display(apriori(df, min_support =ratio, low_memory = True, use_colnames = True))
# Out:
#    support             itemsets
# 0    0.100          (alfajores)
# 1    0.235              (bread)
# 2    0.425             (coffee)
# 3    0.115            (cookies)
# 4    0.115  (hearty & seasonal)
# 5    0.110              (juice)
# 6    0.100             (muffin)
# 7    0.140             (pastry)
# 8    0.105               (soup)
# 9    0.215                (tea)
